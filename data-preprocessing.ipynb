# %% [markdown]
# # Clean, select features and label the samples

# %%
import pandas as pd
from tqdm import tqdm
import numpy as np
import csv
import re

# %%
# Load Newsguard data
newsguard_df = pd.read_csv("data/newsguard_ratings.csv")
newsguard_df
# Out:
#                 identifier     identifierAlt rank  healthGuard country  \
# 0      nanotechnology.news   naturalnews.com    N         True      US
# 1      yorkshirepost.co.uk               NaN    T         True      GB
# 2               davvero.tv               NaN   TK        False     ALL
# 3                  cdc.gov           cdc.gov    T         True      US
# 4         greenmedinfo.com  greenmedinfo.com    N         True      US
# ...                    ...               ...  ...          ...     ...
# 1689    washingtonpost.com               NaN    T         True      US
# 1690         ilpiacenza.it    milanotoday.it    T         True     ALL
# 1691      optimagazine.com               NaN    N         True     ALL
# 1692       reitschuster.de               NaN    N        False     ALL
# 1693  famigliacristiana.it               NaN    T        False     ALL
#
#                             groupName  siteOnline            parent  score  \
# 0     naturalnews.com website network        True   naturalnews.com    5.0
# 1                                 NaN        True               NaN   95.0
# 2                                 NaN        True               NaN    0.0
# 3                                 NaN        True           cdc.gov  100.0
# 4                                 NaN        True  greenmedinfo.com   30.0
# ...                               ...         ...               ...    ...
# 1689                              NaN        True               NaN  100.0
# 1690        citynews websites network        True    milanotoday.it   82.5
# 1691                              NaN        True               NaN   12.5
# 1692                              NaN        True               NaN   59.5
# 1693                              NaN        True               NaN   87.5
#
#                                                 topline
# 0     A &nbsp;site that is part of a network of hund...
# 1     The website of the Yorkshire Post, a daily new...
# 2                                                   NaN
# 3     The website for the U.S. Centers for Disease C...
# 4     A website that has promoted unproven cures for...
# ...                                                 ...
# 1689  The website for The Washington Post, a leading...
# 1690  A network&nbsp;of approximately 50 local newsp...
# 1691  A digital magazine about music and pop culture...
# 1692  A news blog run by journalist Boris Reitschust...
# 1693  The website of Famiglia Cristiana, a weekly Ca...
#
# [1694 rows x 10 columns]

# %%
# Building Newsguard map
newsguard_map = pd.concat([
    newsguard_df[["identifier", "score"]].dropna(),
    newsguard_df[["identifierAlt", "score"]].rename({"identifierAlt": "identifier"}, axis=1).dropna()])

newsguard_map.drop_duplicates(inplace=True)
newsguard_map.sort_values(by="identifier", inplace=True)
newsguard_map.set_index("identifier", inplace=True)
newsguard_map
# Out:
#                      score
# identifier
# 100giornidaleoni.it   30.0
# 10news.com           100.0
# 11alive.com          100.0
# 13wham.com            90.0
# 14news.com           100.0
# ...                    ...
# zdf.de               100.0
# zdnet.com            100.0
# zeit.de               92.5
# zenodo.org             0.0
# zerohedge.com          7.5
#
# [1509 rows x 1 columns]

# %%
newsguard_map.to_csv("newsguard_map.csv")

# %%
# Ratings resolver function
def get_newsguard_ratings(urlist, index_df):
    
    ratings = []
    
    for url in urlist:
        
        try:
            ratings.append(index_df.loc[url.lower()].values[0])
        except KeyError:
            continue
            
    return ratings

# %% [markdown]
# ## Data preprocess

# %%
DATA_SOURCE = "data/tweets_processed_merged_users_2023_02_22.csv"

# %%
# Data columns names
[print(n, x) for n, x in enumerate(pd.read_csv(DATA_SOURCE, nrows=1).columns)];
# Out:
# 0 Unnamed: 0
# 1 tweet_id
# 2 created_at
# 3 user_id
# 4 user_screen_name
# 5 geo
# 6 place
# 7 lang
# 8 truncated
# 9 text
# 10 retweet_count
# 11 likes_count
# 12 retweeted_text
# 13 user_mentions
# 14 hashtags
# 15 urls
# 16 is_quote
# 17 is_reply
# 18 is_original
# 19 is_retweet
# 20 in_reply_to_status_id
# 21 in_reply_to_user_id
# 22 in_reply_to_screen_name
# 23 quoted_text
# 24 retweeted_status_id
# 25 retweeted_user_id
# 26 retweeted_user_screen_name
# 27 quoted_urls
# 28 quoted_hashtags
# 29 quoted_created_at
# 30 quoted_status_id
# 31 quoted_user_id
# 32 quoted_user_screen_name
# 33 media
# 34 positive
# 35 neutral
# 36 negative

# %%
# Manual feature selection
FSELECT = ['tweet_id',
           'created_at',
           'user_id',
           'retweeted_user_id',
           'retweeted_status_id',
           'retweet_count',
           'likes_count',
           'retweeted_text' ]

# reference: https://developer.twitter.com/en/docs/twitter-api/v1/data-dictionary/object-model/tweet

# %% [markdown]
# ## Dataset filtering and re-build

# %%
# Set this to limit the target number of CSV rows to process.
# Set to None to process all rows
ROWS_LIMIT = None #10000


TWEETS = {"corrupted": []}


# Initialize statistics
STATS = {"tweets_processed_count": 0,
         "tweets_corrupted_count": 0,
         
         "tweets_accepted": 0,
         "tweets_accepted_originals": 0,
         "tweets_accepted_retweets": 0,
         "tweets_accepted_replies": 0,
         "tweets_accepted_quotations": 0,
         
         "tweets_with_detected_urls": 0,
         "originals_with_detected_urls": 0,
         "retweets_with_detected_urls": 0,
         "replies_with_detected_urls": 0,
         "quotes_with_detected_urls": 0,
         "quotes_with_detected_urls_strict": 0,
         
         "tweets_with_extracted_urls": 0,
         "originals_with_extracted_urls": 0,
         "retweets_with_extracted_urls": 0,
         "replies_with_extracted_urls": 0,
         "quotes_with_extracted_urls": 0,
         "quotes_with_extracted_urls_strict": 0,
        
         "tweets_with_newsguard_urls": 0,
         "originals_with_newsguard_urls": 0,
         "retweets_with_newsguard_urls": 0,
         "replies_with_newsguard_urls": 0,
         "quotes_with_newsguard_urls": 0,
         "quotes_with_newsguard_urls_strict": 0,
         "dataset_total_samples": 0}

    
#url_pattern = r"(?:(?:https?://(?:www\.)?)|(?:[^\.]www\.))(\w+\.\w+)(?:/?)"
#url_pattern = r"(?:(?:https?://(?:www\.)?)|(?:[^\.]www\.))([A-Za-z]\w+\.\w[A-Za-z]+)(?:/?)"
url_pattern = r"(?:(?:https?://www\.)|(?:https?://)|(?:www\.))([\w.-]+\.\w{2,})(?:(?:/)|(?: )|(?:;))?"

url_regex = re.compile(url_pattern)


# Open two file streams at the same time: source and destination
with (open(DATA_SOURCE, 'r', encoding="utf-8") as csv_src,
      open("data/preprocessed_tweets_dataset.csv", 'w', encoding="utf-8") as csv_dst):
    
    csv_reader = csv.reader(csv_src, delimiter=',')
    csv_writer = csv.writer(csv_dst, delimiter=',', lineterminator='\n')
    
    for n, row in tqdm(enumerate(csv_reader)):
        
        if n == 0:
            
            # First line is the header, read and filter the selected features
            name2idx = {name: idx for idx, name in enumerate(row) if name in FSELECT}
            
            # Sort columns as the order of FSELECT
            name2idx = {f: name2idx[f] for f in FSELECT}
                        
            # Write te new header in the dest file
            newsguard_features = ["root_domains", "newsguard_rating"]
            csv_writer.writerow(list(name2idx.keys()) + newsguard_features)
    
        elif not ROWS_LIMIT or n <= ROWS_LIMIT:
            
            STATS["tweets_processed_count"] += 1
            
            # Values unpacking
            if len(row) == 37:
                # Selected features unpack
                name2value = {k: row[idx] for k, idx in name2idx.items()} 
                # Manual features unpack
                is_original = bool(int(row[18]))
                is_retweet = bool(int(row[19]))
                is_reply = bool(int(row[17]))
                is_quote = bool(int(row[16]))
                text = row[9]
                retweeted_text = row[12]
                quoted_text = row[23]
                urls = row[15]
                quoted_urls = row[27]
            else:
                STATS["tweets_corrupted_count"] += 1
                TWEETS["corrupted"].append(row)
                continue # Skip current iteration                
            
            # Get URLs from text
            original_detected_urls = url_regex.findall(text)
            retweet_detected_urls = url_regex.findall(retweeted_text)
            detected_urls = original_detected_urls + retweet_detected_urls
            quote_detected_urls = url_regex.findall(quoted_text)
            
            # Get URLs from previous preprocess
            extracted_urls = url_regex.findall(urls)
            quote_extracted_urls = url_regex.findall(quoted_urls)
            
            # Get ratings from known urls
            ng_ratings = get_newsguard_ratings(extracted_urls, newsguard_map)
            quoted_ng_ratings = get_newsguard_ratings(quote_extracted_urls, newsguard_map)
                
            # General statistics
            STATS["tweets_accepted"] += 1   # If this iteration go on the tweet is accepted
            STATS["tweets_accepted_originals"] += 1 if is_original else 0
            STATS["tweets_accepted_retweets"] += 1 if is_retweet else 0
            STATS["tweets_accepted_replies"] += 1 if is_reply else 0
            STATS["tweets_accepted_quotations"] += 1 if is_quote else 0
            
            # Detected urls with regex statistics
            STATS["tweets_with_detected_urls"] += 1 if detected_urls else 0
            STATS["originals_with_detected_urls"] += 1 if detected_urls and is_original else 0
            STATS["retweets_with_detected_urls"] += 1 if detected_urls and is_retweet else 0
            STATS["replies_with_detected_urls"] += 1 if detected_urls and is_reply else 0
            STATS["quotes_with_detected_urls"] += 1 if detected_urls and is_quote else 0
            STATS["quotes_with_detected_urls_strict"] += 1 if detected_urls and quote_detected_urls else 0
            
            # Extracted urls with previous preprocessing (resolved urls)
            STATS["tweets_with_extracted_urls"] += 1 if extracted_urls else 0
            STATS["originals_with_extracted_urls"] += 1 if extracted_urls and is_original else 0
            STATS["retweets_with_extracted_urls"] += 1 if extracted_urls and is_retweet else 0
            STATS["replies_with_extracted_urls"] += 1 if extracted_urls and is_reply else 0
            STATS["quotes_with_extracted_urls"] += 1 if extracted_urls and is_quote else 0
            STATS["quotes_with_extracted_urls_strict"] += 1 if extracted_urls and quote_extracted_urls else 0
            
            # Newsguard resolved urls
            STATS["tweets_with_newsguard_urls"] += 1 if ng_ratings else 0
            STATS["originals_with_newsguard_urls"] += 1 if ng_ratings and is_original else 0
            STATS["retweets_with_newsguard_urls"] += 1 if ng_ratings and is_retweet else 0
            STATS["replies_with_newsguard_urls"] += 1 if ng_ratings and is_reply else 0
            STATS["quotes_with_newsguard_urls"] += 1 if ng_ratings and is_quote else 0
            STATS["quotes_with_newsguard_urls_strict"] += 1 if ng_ratings and quoted_ng_ratings else 0
            
            # Output file
            if (is_retweet or is_original) and ng_ratings:
                
                STATS["dataset_total_samples"] += 1
                
                # Format and add Newsguard data to current row
                root_domains = " ".join(extracted_urls) # e.g. "root.domain.com \nfoo.bar.it \nzenodo.org"
                newsguard_rating = np.mean(ng_ratings)
                ng_info = [root_domains, newsguard_rating]

                # Write the new row in the destination file
                csv_writer.writerow(list(name2value.values()) + ng_info)
           
        else:

            break # When ROWS_LIMIT is not None this will stop the reading loop
# Out:
# 12686129it [03:47, 55854.66it/s]

# %%
STATS
# Out:
# {'tweets_processed_count': 12686128,
#  'tweets_corrupted_count': 195,
#  'tweets_accepted': 12685933,
#  'tweets_accepted_originals': 1849092,
#  'tweets_accepted_retweets': 6732008,
#  'tweets_accepted_replies': 2066315,
#  'tweets_accepted_quotations': 2038518,
#  'tweets_with_detected_urls': 5113166,
#  'originals_with_detected_urls': 1221037,
#  'retweets_with_detected_urls': 3362249,
#  'replies_with_detected_urls': 217739,
#  'quotes_with_detected_urls': 312141,
#  'quotes_with_detected_urls_strict': 213464,
#  'tweets_with_extracted_urls': 2041006,
#  'originals_with_extracted_urls': 1023646,
#  'retweets_with_extracted_urls': 629788,
#  'replies_with_extracted_urls': 144261,
#  'quotes_with_extracted_urls': 243311,
#  'quotes_with_extracted_urls_strict': 97586,
#  'tweets_with_newsguard_urls': 909488,
#  'originals_with_newsguard_urls': 449129,
#  'retweets_with_newsguard_urls': 378101,
#  'replies_with_newsguard_urls': 74101,
#  'quotes_with_newsguard_urls': 8157,
#  'quotes_with_newsguard_urls_strict': 2095,
#  'dataset_total_samples': 827230}

# %%
# Corrupted tweets have a different number of fields (IndexError)
# Sometimes 'id' is missing (very important field) so they've skipped
# Here the corrupted tweets can be inspected
[print(x, '\n') for x in TWEETS["corrupted"]];
# Out:
# ['32470', '1341025614191599616', '2020-12-21 14:19:56+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '', '‘Lecito’ vaccino anti Covid anche se usate linee cellulari provenienti da feti abortiti']
#
# ['https://t.co/iH61nUdeeH', '2', '3', '', '', '', 'https://tinyurl.com/yaz3svdh;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['34093', '1341037286423732226', '2020-12-21 15:06:19+00:00', '993080715116937216', 'fordeborah5', '', '', 'it', '', '', '2', '0', '‘Lecito’ vaccino anti Covid anche se usate linee cellulari provenienti da feti abortiti']
#
# ['https://t.co/iH61nUdeeH', 'AsiaNewsIT;', '', 'https://tinyurl.com/yaz3svdh;', '0', '0', '0', '1', '', '', '', '', '1341025614191599616', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['485344', '1343925691511939073', '2020-12-29 14:23:48+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'C’è una responsabilità morale ad accettare il vaccino']
#
# ['https://t.co/2ltUs4Ukm2', '0', '0', '', '', '', 'https://tinyurl.com/y9kncvst;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['505493', '1343983266915868677', '2020-12-29 18:12:35+00:00', '993080715116937216', 'fordeborah5', '', '', 'it', '0.0', '', '0', '0', 'C’è una responsabilità morale ad accettare il vaccino']
#
# ['https://t.co/2ltUs4Ukm2', 'AsiaNewsIT;', '', 'https://tinyurl.com/y9kncvst;', '0', '0', '0', '1', '', '', '', '', '1343925691511939073', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['515448', '1344009730302353413', '2020-12-29 19:57:44+00:00', '869133153264422912', 'VaticanIHD', '', '', 'it', '0.0', '', '0', '0', 'C’è una responsabilità morale ad accettare il vaccino']
#
# ['https://t.co/2ltUs4Ukm2', 'AsiaNewsIT;', '', 'https://tinyurl.com/y9kncvst;', '0', '0', '0', '1', '', '', '', '', '1343925691511939073', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['544808', '1344198518039334912', '2020-12-30 08:27:55+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Teheran sperimenta il primo vaccino ‘made in Iran’ contro il Covid']
#
# ['https://t.co/z2YZxMJBhy', '0', '0', '', '', '', 'https://tinyurl.com/yamolntn;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['549259', '1344211272120872961', '2020-12-30 09:18:36+00:00', '1239838228120768512', 'BroglieRebecca', '', '', 'it', '0.0', '', '0', '0', 'C’è una responsabilità morale ad accettare il vaccino']
#
# ['https://t.co/2ltUs4Ukm2', 'AsiaNewsIT;', '', 'https://tinyurl.com/y9kncvst;', '0', '0', '0', '1', '', '', '', '', '1343925691511939073', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['560115', '1344247094715027457', '2020-12-30 11:40:56+00:00', '993080715116937216', 'fordeborah5', '', '', 'it', '0.0', '', '0', '0', 'Teheran sperimenta il primo vaccino ‘made in Iran’ contro il Covid']
#
# ['https://t.co/z2YZxMJBhy', 'AsiaNewsIT;', '', 'https://tinyurl.com/yamolntn;', '0', '0', '0', '1', '', '', '', '', '1344198518039334912', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['844789', '1346021495433285633', '2021-01-04 09:11:47+00:00', '58817857', 'Democraticist', '', '', 'en', '0.0', '#Covid19']
#
# ['#Vaccinations']
#
# ['#VisualData in the #World']
#
# []
#
# ['https://t.co/beKHe4vN3p', '0', '0', '', '', 'Covid19;Vaccinations;VisualData;World;', 'https://lab.gedidigital.it/gedi-visual/2020/coronavirus-le-vaccinazioni-nel-mondo/?ref=RHHD-T;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['1009473', '1347156154288373760', '2021-01-07 12:20:30+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'L’Indonesia discute se il vaccino per il Covid è ammissibile per l’Islam']
#
# ['https://t.co/oMezsYCmDD', '0', '0', '', '', '', 'https://tinyurl.com/y4kmh2fk;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['1077540', '1348183118075858944', '2021-01-10 08:21:18+00:00', '887231727143456768', 'Rossana86448038', '', '', 'it', '0.0', 'Sui vaccini ']
#
# ['millantano record per coprire i ritardi https://t.co/UiSX9LKNeu', '0', '0', '', '', '', 'https://www.laverita.info/ci-risiamo-conte-si-loda-per-coprire-linefficienza-2649795881.html;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['1158187', '1349058765757313027', '2021-01-12 18:20:48+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Il Bangladesh attende la vaccinazione contro il coronavirus']
#
# ['https://t.co/u9DbUhRzQw', '0', '0', '', '', '', 'https://tinyurl.com/y3awmbrr;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['1354945', '1351519838448005120', '2021-01-19 13:20:14+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Vescovi filippini: il vaccino ai poveri prima che a noi']
#
# ['https://t.co/nbLZXt3M8Q', '0', '0', '', '', '', 'https://tinyurl.com/y5yamn25;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['1357821', '1351536877971628032', '2021-01-19 14:27:56+00:00', '999645834', 'MarisaLevi1', '', '', 'it', '0.0', '', '0', '0', 'Vescovi filippini: il vaccino ai poveri prima che a noi']
#
# ['https://t.co/nbLZXt3M8Q', 'AsiaNewsIT;', '', 'https://tinyurl.com/y5yamn25;', '0', '0', '0', '1', '', '', '', '', '1351519838448005120', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['1546458', '1353997229032407041', '2021-01-26 09:24:30+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '', 'L’economia di Seoul resiste al Covid. Pyongyang vuole i vaccini usati dal Sud ']
#
# ['https://t.co/UKtgcJ1N14', '1', '1', '', '', '', 'https://tinyurl.com/yyb7qnze;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['1546909', '1354004110438227969', '2021-01-26 09:51:50+00:00', '993080715116937216', 'fordeborah5', '', '', 'it', '0.0', '', '0', '0', 'L’economia di Seoul resiste al Covid. Pyongyang vuole i vaccini usati dal Sud ']
#
# ['https://t.co/UKtgcJ1N14', 'AsiaNewsIT;', '', 'https://tinyurl.com/yyb7qnze;', '0', '0', '0', '1', '', '', '', '', '1353997229032407041', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['1739436', '1356912902121398273', '2021-02-03 10:30:20+00:00', '58817857', 'Democraticist', '', '', 'en', '0.0', 'Health All updates on #AntiCovid #vaccines ']
#
# []
#
# ['https://t.co/QipqmkD9zZ', '0', '0', '', '', 'AntiCovid;vaccines;', 'https://translate.google.co.uk/translate?hl=en&sl=it&u=https://www.focus.it/scienza/salute/approvazione-vaccini-covid-aggiornamenti&prev=search&pto=aue;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['1743664', '1356986957172269059', '2021-02-03 15:24:36+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', "Vaccini anti-Covid: la lotta dell'islam fra 'permesso' e 'proibito' "]
#
# ['https://t.co/SEEndrdtdL', '0', '0', '', '', '', 'https://tinyurl.com/y2jwwtsm;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['1988006', '1362013901773299713', '2021-02-17 12:19:53+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Stop al vaccino Pfizer-BioNTech per Taipei: si sospetta la mano di Pechino']
#
# ['https://t.co/rYxjaQnSPO', '0', '0', '', '', '', 'https://tinyurl.com/y7c48vqs;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['2147897', '1364129075367972865', '2021-02-23 08:24:50+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Seoul inizia a vaccinare contro il Covid: più del 50 dei sudcoreani non vuole']
#
# ['https://t.co/SFWteeLLLt', '0', '0', '', '', '', 'https://tinyurl.com/yd7lbw4s;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['2148439', '1364133547708190721', '2021-02-23 08:42:36+00:00', '1103152945', 'TarabellAlberto', '', '', 'it', '1.0', 'Fino ad oggi la Corea del Sud ha risposto molto bene alla pandemia #coronavirus #COVID19... segnatevelo! https://t.co/TfWZMURb8L', '0', '0', '', '', 'coronavirus;COVID19;', '', '1', '0', '0', '0', '', '', '', 'Seoul inizia a vaccinare contro il Covid: più del 50 dei sudcoreani non vuole']
#
# ['https://t.co/SFWteeLLLt', '', '', '', 'https://tinyurl.com/yd7lbw4s;', '', '2021-02-23 08:24:50+00:00', '1364129075367972865', '111260090', 'AsiaNewsIT', '', '', '', '']
#
# ['2149534', '1364143018777997314', '2021-02-23 09:20:14+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'La diplomazia del vaccino fra Israele e Siria (con la mediazione di Mosca)']
#
# ['https://t.co/pR26fgh3qX', '0', '0', '', '', '', 'https://tinyurl.com/y9c46zjg;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['2149627', '1364143813145591808', '2021-02-23 09:23:24+00:00', '1215678906939990016', 'ziolions4219', '', '', 'it', '0.0', '', '0', '0', 'La diplomazia del vaccino fra Israele e Siria (con la mediazione di Mosca)']
#
# ['https://t.co/pR26fgh3qX', 'AsiaNewsIT;', '', 'https://tinyurl.com/y9c46zjg;', '0', '0', '0', '1', '', '', '', '', '1364143018777997314', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['2150479', '1364150118807728128', '2021-02-23 09:48:27+00:00', '1261752897404051456', 'Arizona0404', '', '', 'und', '0.0', '#Asia #CoreaDelSud #vaccini #vaccino #coronavirus #COVID19 \n#23febbraio #rassegnastampa', '0', '0', '', '', 'Asia;CoreaDelSud;vaccini;vaccino;coronavirus;COVID19;23febbraio;rassegnastampa;', '', '1', '0', '0', '0', '', '', '', 'Seoul inizia a vaccinare contro il Covid: più del 50 dei sudcoreani non vuole']
#
# ['https://t.co/SFWteeLLLt', '', '', '', 'https://tinyurl.com/yd7lbw4s;', '', '2021-02-23 08:24:50+00:00', '1364129075367972865', '111260090', 'AsiaNewsIT', '', '', '', '']
#
# ['2184421', '1364506524693987330', '2021-02-24 09:24:41+00:00', '111260090', 'AsiaNewsIT', '', '', 'tl', '0.0', 'Attacco hacker di Pyongyang alla Pfizer: vaccino anti-Covid nel mirino']
#
# ['https://t.co/bqxWPPVMaC', '0', '0', '', '', '', 'https://tinyurl.com/yaw3wr48;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['2442544', '1366786923646365699', '2021-03-02 16:26:10+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Ministro saudita: vaccino contro il Covid è ‘precondizione’ per l’Hajj']
#
# ['https://t.co/PSX6qnQbnA', '0', '0', '', '', '', 'https://tinyurl.com/ydfkj8er;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['2514612', '1367419700578312194', '2021-03-04 10:20:36+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Vaccinato il card. Gracias che dice: vaccinarsi è un atto di carità verso gli altri']
#
# ['https://t.co/0PERZ6RUWR', '0', '0', '', '', '', 'https://tinyurl.com/y833njry;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['2692728', '1369204153562587137', '2021-03-09 08:31:23+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Tokyo stanzia 41 milioni di dollari per vaccinare 25 Paesi dell’Asia-Pacifico']
#
# ['https://t.co/C7PRdn1RY3', '0', '0', '', '', '', 'https://tinyurl.com/y8hum93r;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['2709405', '1369278028744916997', '2021-03-09 13:24:56+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Pandemia: l’86 dei vaccini usati in America Latina è asiatico']
#
# ['https://t.co/nygeUsnYMv', '0', '0', '', '', '', 'https://tinyurl.com/y7rnpuv5;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['2758297', '1369610189280849924', '2021-03-10 11:24:49+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Il 76 dei taiwanesi non vuole i vaccini cinesi contro il Covid']
#
# ['https://t.co/lW7498A816', '0', '0', '', '', '', 'https://tinyurl.com/y74vqckg;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['2758331', '1369610348869849090', '2021-03-10 11:25:27+00:00', '1495539583', 'SurrexitVere', '', '', 'it', '0.0', '', '0', '0', 'Il 76 dei taiwanesi non vuole i vaccini cinesi contro il Covid']
#
# ['https://t.co/lW7498A816', 'AsiaNewsIT;', '', 'https://tinyurl.com/y74vqckg;', '0', '0', '0', '1', '', '', '', '', '1369610189280849924', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['2759151', '1369613797829251072', '2021-03-10 11:39:10+00:00', '785129133009494021', 'thewaterflea', '', '', 'it', '0.0', '', '0', '0', 'Il 76 dei taiwanesi non vuole i vaccini cinesi contro il Covid']
#
# ['https://t.co/lW7498A816', 'AsiaNewsIT;', '', 'https://tinyurl.com/y74vqckg;', '0', '0', '0', '1', '', '', '', '', '1369610189280849924', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['2764996', '1369640368556359685', '2021-03-10 13:24:45+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Vescovi indiani: accettabile il vaccino anti-Covid anche se sviluppato da feti abortiti']
#
# ['https://t.co/me7fYVKDfl', '0', '0', '', '', '', 'https://tinyurl.com/yaogodtw;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['2994859', '1370681654134595584', '2021-03-13 10:22:27+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Summit Quad: un miliardo di dosi del vaccino anti-Covid per l’Asia-Pacifico']
#
# ['https://t.co/IyrCcv7Ltr', '0', '0', '', '', '', 'https://tinyurl.com/yehx2dv7;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['2995304', '1370683029329489921', '2021-03-13 10:27:54+00:00', '1215678906939990016', 'ziolions4219', '', '', 'it', '0.0', '', '0', '0', 'Summit Quad: un miliardo di dosi del vaccino anti-Covid per l’Asia-Pacifico']
#
# ['https://t.co/IyrCcv7Ltr', 'AsiaNewsIT;', '', 'https://tinyurl.com/yehx2dv7;', '0', '0', '0', '1', '', '', '', '', '1370681654134595584', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['3013924', '1370757787249217542', '2021-03-13 15:24:58+00:00', '1326985193362780162', 'luigi_ramozzi', '', '', 'it', '0.0', '', '0', '0', 'Summit Quad: un miliardo di dosi del vaccino anti-Covid per l’Asia-Pacifico']
#
# ['https://t.co/IyrCcv7Ltr', 'AsiaNewsIT;', '', 'https://tinyurl.com/yehx2dv7;', '0', '0', '0', '1', '', '', '', '', '1370681654134595584', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['3347954', '1371888963447836672', '2021-03-16 18:19:52+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Arrestata attivista cambogiana:  ha criticato il vaccino cinese anti-Covid']
#
# ['https://t.co/K6qlPiasjK', '0', '0', '', '', '', 'https://tinyurl.com/yfd5aej8;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['3418642', '1372194910586175504', '2021-03-17 14:35:35+00:00', '49744213', 'francesconuccio', '', '', 'it', '0.0', '', '0', '0', 'Arrestata attivista cambogiana:  ha criticato il vaccino cinese anti-Covid']
#
# ['https://t.co/K6qlPiasjK', 'AsiaNewsIT;', '', 'https://tinyurl.com/yfd5aej8;', '0', '0', '0', '1', '', '', '', '', '1371888963447836672', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['3697361', '1373881106987106306', '2021-03-22 06:15:56+00:00', '1251012809477021696', 'DonatellaN2', '', '', 'it', '1.0', 'i #medici di medicina generale dovrebbero agevolare le #cure per non  portare in sofferenza gli #ospedali anche per il rispetto dei nostri #eroi che incessantemente lottano contro il #COVID19.']
#
# [' il #VaccinoAntiCovid andrebbe garantito a tutti nel più breve tempo possibile.', '0', '0', '', '', 'medici;cure;ospedali;eroi;COVID19;VaccinoAntiCovid;', '', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['3724176', '1373972810209619968', '2021-03-22 12:20:19+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Israele al voto: da Netanyahu vaccini anti-Covid e aiuti per restare al potere']
#
# ['https://t.co/HMChNFNFbq', '0', '0', '', '', '', 'https://tinyurl.com/ydt6uyy4;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['3739840', '1374025527166697478', '2021-03-22 15:49:48+00:00', '1326985193362780162', 'luigi_ramozzi', '', '', 'it', '0.0', '', '0', '0', 'Israele al voto: da Netanyahu vaccini anti-Covid e aiuti per restare al potere']
#
# ['https://t.co/HMChNFNFbq', 'AsiaNewsIT;', '', 'https://tinyurl.com/ydt6uyy4;', '0', '0', '0', '1', '', '', '', '', '1373972810209619968', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['3741691', '1374033181448548357', '2021-03-22 16:20:13+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Ulema indonesiani: il vaccino AstraZeneca lecito ‘in caso di emergenza’']
#
# ['https://t.co/boZhBHqXEH', '0', '0', '', '', '', 'https://tinyurl.com/yfwx2zgy;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['3791470', '1374323876197466115', '2021-03-23 11:35:20+00:00', '1326985193362780162', 'luigi_ramozzi', '', '', 'it', '0.0', '', '0', '0', 'Ulema indonesiani: il vaccino AstraZeneca lecito ‘in caso di emergenza’']
#
# ['https://t.co/boZhBHqXEH', 'AsiaNewsIT;', '', 'https://tinyurl.com/yfwx2zgy;', '0', '0', '0', '1', '', '', '', '', '1374033181448548357', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['3958413', '1375424303685058567', '2021-03-26 12:28:02+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', '_la Penitenzieria apostolica lancia un ‘vaccino sospeso’ per i più vulnerabili']
#
# ['https://t.co/rlYKzELXnt', '0', '0', '', '', '', 'https://tinyurl.com/yjrfydfq;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['4607862', '1380467707481579526', '2021-04-09 10:28:43+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Pechino è prima nell’export del vaccino contro il Covid-19']
#
# ['https://t.co/NYKkiMDyEN', '0', '0', '', '', '', 'https://tinyurl.com/ydwoo79v;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['4616036', '1380504465380376579', '2021-04-09 12:54:47+00:00', '1326985193362780162', 'luigi_ramozzi', '', '', 'it', '0.0', '', '0', '0', 'Pechino è prima nell’export del vaccino contro il Covid-19']
#
# ['https://t.co/NYKkiMDyEN', 'AsiaNewsIT;', '', 'https://tinyurl.com/ydwoo79v;', '0', '0', '0', '1', '', '', '', '', '1380467707481579526', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['4744762', '1381524439188307968', '2021-04-12 08:27:48+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Scienziati di Pechino: I nostri vaccini anti-Covid hanno scarsa efficacia']
#
# ['https://t.co/RN7WWjK2Sj', '0', '0', '', '', '', 'https://tinyurl.com/yhc8pycy;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['4757825', '1381588225450463235', '2021-04-12 12:41:16+00:00', '1326985193362780162', 'luigi_ramozzi', '', '', 'it', '0.0', '', '0', '0', 'Scienziati di Pechino: I nostri vaccini anti-Covid hanno scarsa efficacia']
#
# ['https://t.co/RN7WWjK2Sj', 'AsiaNewsIT;', '', 'https://tinyurl.com/yhc8pycy;', '0', '0', '0', '1', '', '', '', '', '1381524439188307968', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['4851940', '1382293432404688897', '2021-04-14 11:23:30+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Chiesa coreana partecipa a campagna di condivisione dei vaccini promossa dal Papa']
#
# ['https://t.co/ecqbxL01n0', '0', '0', '', '', '', 'https://tinyurl.com/yexx347g;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['4853465', '1382300821203906561', '2021-04-14 11:52:52+00:00', '376378946', 'AgenziaH', '', '', 'it', '0.0', '', '0', '0', 'Chiesa coreana partecipa a campagna di condivisione dei vaccini promossa dal Papa']
#
# ['https://t.co/ecqbxL01n0', 'AsiaNewsIT;', '', 'https://tinyurl.com/yexx347g;', '0', '0', '0', '1', '', '', '', '', '1382293432404688897', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['5645486', '1393118986947158017', '2021-05-14 08:20:24+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Taipei lancia il suo vaccino contro il Covid-19']
#
# ['https://t.co/CeTOLfSU6L', '0', '0', '', '', '', 'https://tinyurl.com/yfcc4lnl;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['5947104', '1397091317965074433', '2021-05-25 07:25:01+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Hong Kong: la gente rifiuta il vaccino anti-Covid. Milioni di dosi rischiano di scadere  ']
#
# ['https://t.co/QqJiMFoGM9', '0', '0', '', '', '', 'https://tinyurl.com/ygr6env7;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['5947254', '1397093149219110913', '2021-05-25 07:32:18+00:00', '1277344448389820416', 'BidellaStella', '', '', 'und', '0.0', '#25maggio #HongKong #vaccino #BuongiornoATutti', '0', '0', '', '', '25maggio;HongKong;vaccino;BuongiornoATutti;', '', '1', '0', '0', '0', '', '', '', 'Hong Kong: la gente rifiuta il vaccino anti-Covid. Milioni di dosi rischiano di scadere  ']
#
# ['https://t.co/QqJiMFoGM9', '', '', '', 'https://tinyurl.com/ygr6env7;', '', '2021-05-25 07:25:01+00:00', '1397091317965074433', '111260090', 'AsiaNewsIT', '', '', '', '']
#
# ['5951708', '1397150238343897088', '2021-05-25 11:19:09+00:00', '962681176526852096', 'miia_2018', '', '', 'it', '', '', '7', '0', 'Hong Kong: la gente rifiuta il vaccino anti-Covid. Milioni di dosi rischiano di scadere  ']
#
# ['https://t.co/QqJiMFoGM9', 'AsiaNewsIT;', '', 'https://tinyurl.com/ygr6env7;', '0', '0', '0', '1', '', '', '', '', '1397091317965074433', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['5951731', '1397150532897230851', '2021-05-25 11:20:19+00:00', '1238143563017474049', 'Flavr7', '', '', 'it', '', '', '7', '0', 'Hong Kong: la gente rifiuta il vaccino anti-Covid. Milioni di dosi rischiano di scadere  ']
#
# ['https://t.co/QqJiMFoGM9', 'AsiaNewsIT;', '', 'https://tinyurl.com/ygr6env7;', '0', '0', '0', '1', '', '', '', '', '1397091317965074433', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['5951891', '1397152653533224960', '2021-05-25 11:28:45+00:00', '2252899982', 'JPCK72', '', '', 'it', '', '', '7', '0', 'Hong Kong: la gente rifiuta il vaccino anti-Covid. Milioni di dosi rischiano di scadere  ']
#
# ['https://t.co/QqJiMFoGM9', 'AsiaNewsIT;', '', 'https://tinyurl.com/ygr6env7;', '0', '0', '0', '1', '', '', '', '', '1397091317965074433', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['5952352', '1397157559744835586', '2021-05-25 11:48:14+00:00', '1337835585034186753', 'cinzia49227255', '', '', 'it', '', '', '7', '0', 'Hong Kong: la gente rifiuta il vaccino anti-Covid. Milioni di dosi rischiano di scadere  ']
#
# ['https://t.co/QqJiMFoGM9', 'AsiaNewsIT;', '', 'https://tinyurl.com/ygr6env7;', '0', '0', '0', '1', '', '', '', '', '1397091317965074433', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['5955751', '1397199157383794693', '2021-05-25 14:33:32+00:00', '1203887463074344960', 'Lukyluke311', '', '', 'it', '', '', '7', '0', 'Hong Kong: la gente rifiuta il vaccino anti-Covid. Milioni di dosi rischiano di scadere  ']
#
# ['https://t.co/QqJiMFoGM9', 'AsiaNewsIT;', '', 'https://tinyurl.com/ygr6env7;', '0', '0', '0', '1', '', '', '', '', '1397091317965074433', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['5957422', '1397218295766528017', '2021-05-25 15:49:35+00:00', '1285295149082447872', 'Pixty3', '', '', 'it', '0.0', '', '0', '0', 'Hong Kong: la gente rifiuta il vaccino anti-Covid. Milioni di dosi rischiano di scadere  ']
#
# ['https://t.co/QqJiMFoGM9', 'AsiaNewsIT;', '', 'https://tinyurl.com/ygr6env7;', '0', '0', '0', '1', '', '', '', '', '1397091317965074433', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['5958422', '1397226929959354368', '2021-05-25 16:23:53+00:00', '1103152945', 'TarabellAlberto', '', '', 'it', '0.0', '', '0', '0', 'Hong Kong: la gente rifiuta il vaccino anti-Covid. Milioni di dosi rischiano di scadere  ']
#
# ['https://t.co/QqJiMFoGM9', 'AsiaNewsIT;', '', 'https://tinyurl.com/ygr6env7;', '0', '0', '0', '1', '', '', '', '', '1397091317965074433', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['5958832', '1397230677066649607', '2021-05-25 16:38:47+00:00', '1193780617', 'IMoresi', '', '', 'it', '0.0', '', '0', '0', 'Hong Kong: la gente rifiuta il vaccino anti-Covid. Milioni di dosi rischiano di scadere  ']
#
# ['https://t.co/QqJiMFoGM9', 'AsiaNewsIT;', '', 'https://tinyurl.com/ygr6env7;', '0', '0', '0', '1', '', '', '', '', '1397091317965074433', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['5958923', '1397231510403563526', '2021-05-25 16:42:06+00:00', '1121163421498712064', 'RinoSimeoni', '', '', 'it', '0.0', '', '0', '0', 'Hong Kong: la gente rifiuta il vaccino anti-Covid. Milioni di dosi rischiano di scadere  ']
#
# ['https://t.co/QqJiMFoGM9', 'AsiaNewsIT;', '', 'https://tinyurl.com/ygr6env7;', '0', '0', '0', '1', '', '', '', '', '1397091317965074433', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['5958934', '1397231593241124865', '2021-05-25 16:42:25+00:00', '1037003822', 'DFailli', '', '', 'it', '0.0', '', '0', '0', 'Hong Kong: la gente rifiuta il vaccino anti-Covid. Milioni di dosi rischiano di scadere  ']
#
# ['https://t.co/QqJiMFoGM9', 'AsiaNewsIT;', '', 'https://tinyurl.com/ygr6env7;', '0', '0', '0', '1', '', '', '', '', '1397091317965074433', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['5960190', '1397243859768385542', '2021-05-25 17:31:10+00:00', '4570179557', 'baratto_m', '', '', 'it', '0.0', 'Se fosse vero sarebbe drammatico', '0', '0', '', '', '', '', '1', '0', '0', '0', '', '', '', 'Hong Kong: la gente rifiuta il vaccino anti-Covid. Milioni di dosi rischiano di scadere  ']
#
# ['https://t.co/QqJiMFoGM9', '', '', '', 'https://tinyurl.com/ygr6env7;', '', '2021-05-25 07:25:01+00:00', '1397091317965074433', '111260090', 'AsiaNewsIT', '', '', '', '']
#
# ['5960267', '1397244596778831874', '2021-05-25 17:34:06+00:00', '1384848469614071810', 'nadoaljhjdjddk', '', '', 'it', '0.0', 'RT @baratto_m: Se fosse vero sarebbe drammatico', '0', '0', '', 'baratto_m;', '', '', '1', '0', '0', '0', '', '', '', 'Hong Kong: la gente rifiuta il vaccino anti-Covid. Milioni di dosi rischiano di scadere  ']
#
# ['https://t.co/QqJiMFoGM9', '', '', '', 'https://tinyurl.com/ygr6env7;', '', '2021-05-25 07:25:01+00:00', '1397091317965074433', '111260090', 'AsiaNewsIT', '', '', '', '']
#
# ['5969895', '1397321216218836993', '2021-05-25 22:38:33+00:00', '1699728120', 'argentofisico', '', '', 'it', '0.0', '', '0', '0', 'Hong Kong: la gente rifiuta il vaccino anti-Covid. Milioni di dosi rischiano di scadere  ']
#
# ['https://t.co/QqJiMFoGM9', 'AsiaNewsIT;', '', 'https://tinyurl.com/ygr6env7;', '0', '0', '0', '1', '', '', '', '', '1397091317965074433', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['5981153', '1397498219492487172', '2021-05-26 10:21:54+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Tsai Ing-wen: Pechino ha bloccato i nostri acquisti di vaccini Pfizer-BioNTech']
#
# ['https://t.co/k5csJsJjeC', '0', '0', '', '', '', 'https://tinyurl.com/yg28pbcz;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['5981242', '1397498929810493440', '2021-05-26 10:24:43+00:00', '312213441', 'abigail_aqp', '', '', 'it', '0.0', '', '0', '0', 'Tsai Ing-wen: Pechino ha bloccato i nostri acquisti di vaccini Pfizer-BioNTech']
#
# ['https://t.co/k5csJsJjeC', 'AsiaNewsIT;', '', 'https://tinyurl.com/yg28pbcz;', '0', '0', '0', '1', '', '', '', '', '1397498219492487172', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['5981460', '1397501052346413065', '2021-05-26 10:33:09+00:00', '999645834', 'MarisaLevi1', '', '', 'it', '0.0', '', '0', '0', 'Tsai Ing-wen: Pechino ha bloccato i nostri acquisti di vaccini Pfizer-BioNTech']
#
# ['https://t.co/k5csJsJjeC', 'AsiaNewsIT;', '', 'https://tinyurl.com/yg28pbcz;', '0', '0', '0', '1', '', '', '', '', '1397498219492487172', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['5981510', '1397501622784253957', '2021-05-26 10:35:25+00:00', '49744213', 'francesconuccio', '', '', 'it', '0.0', '', '0', '0', 'Tsai Ing-wen: Pechino ha bloccato i nostri acquisti di vaccini Pfizer-BioNTech']
#
# ['https://t.co/k5csJsJjeC', 'AsiaNewsIT;', '', 'https://tinyurl.com/yg28pbcz;', '0', '0', '0', '1', '', '', '', '', '1397498219492487172', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['6414813', '1401952271890583554', '2021-06-07 17:20:43+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Covid-19: Tokyo invierà dosi di vaccino ad Hanoi']
#
# ['https://t.co/BvkULoieRk', '0', '0', '', '', '', 'https://tinyurl.com/y6rg2qey;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['6893920', '1405154917342498820', '2021-06-16 13:26:53+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Hasina: con Seoul un centro per la produzione in loco dei vaccini']
#
# ['https://t.co/TXEHTMbBgR', '0', '0', '', '', '', 'https://tinyurl.com/yj4xq9nb;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['6988730', '1406149968382074881', '2021-06-19 07:20:52+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Mosca: obbligo di vaccinazione contro il Covid']
#
# ['https://t.co/YcPCXZjOCz', '0', '0', '', '', '', 'https://tinyurl.com/yzv5zflg;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['6989888', '1406156803365298181', '2021-06-19 07:48:01+00:00', '1016310193', 'MauroPastori2', '', '', 'it', '0.0', '', '0', '0', 'Mosca: obbligo di vaccinazione contro il Covid']
#
# ['https://t.co/YcPCXZjOCz', 'AsiaNewsIT;', '', 'https://tinyurl.com/yzv5zflg;', '0', '0', '0', '1', '', '', '', '', '1406149968382074881', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['6995711', '1406195700505923586', '2021-06-19 10:22:35+00:00', '49744213', 'francesconuccio', '', '', 'it', '0.0', '', '0', '0', 'Mosca: obbligo di vaccinazione contro il Covid']
#
# ['https://t.co/YcPCXZjOCz', 'AsiaNewsIT;', '', 'https://tinyurl.com/yzv5zflg;', '0', '0', '0', '1', '', '', '', '', '1406149968382074881', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['7153986', '1408326470947201026', '2021-06-25 07:29:30+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Tokyo dona a Taipei un altro milione di vaccini anti-Covid']
#
# ['https://t.co/eZ2tO8Itpc', '0', '0', '', '', '', 'https://tinyurl.com/yzyfowao;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['7516461', '1413428128802869248', '2021-07-09 09:21:40+00:00', '111260090', 'AsiaNewsIT', '', '', 'und', '0.0', 'Covid-19: Pyongyang rifiuta i vaccini AstraZeneca']
#
# ['https://t.co/4axUTu4Xny', '0', '0', '', '', '', 'https://tinyurl.com/yjvsgun9;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['7586783', '1414574650835750918', '2021-07-12 13:17:32+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Lotta al Covid: i giganti taiwanesi dell’hi-tech donano 10 milioni di vaccini al loro governo']
#
# ['https://t.co/g4q0GqInV1', '0', '0', '', '', '', 'https://tinyurl.com/ygmrdhq3;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['7699855', '1415315209531580416', '2021-07-14 14:20:15+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Jakarta: medici e infermieri continuano a morire malgrado le vaccinazioni']
#
# ['https://t.co/3YXR90Wsf7', '0', '0', '', '', '', 'https://tinyurl.com/yza7ej4k;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['7700903', '1415319954925178889', '2021-07-14 14:39:07+00:00', '942914288821460992', 'ClaraPorta4', '', '', 'it', '0.0', '', '0', '0', 'Jakarta: medici e infermieri continuano a morire malgrado le vaccinazioni']
#
# ['https://t.co/3YXR90Wsf7', 'AsiaNewsIT;', '', 'https://tinyurl.com/yza7ej4k;', '0', '0', '0', '1', '', '', '', '', '1415315209531580416', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['7703482', '1415331106908516355', '2021-07-14 15:23:26+00:00', '49744213', 'francesconuccio', '', '', 'it', '0.0', '', '0', '0', 'Jakarta: medici e infermieri continuano a morire malgrado le vaccinazioni']
#
# ['https://t.co/3YXR90Wsf7', 'AsiaNewsIT;', '', 'https://tinyurl.com/yza7ej4k;', '0', '0', '0', '1', '', '', '', '', '1415315209531580416', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['8015668', '1417036457949159425', '2021-07-19 08:19:53+00:00', '111260090', 'AsiaNewsIT', '', '', 'ro', '0.0', 'Biškek: una fatwa a favore della vaccinazione contro il Covid']
#
# ['https://t.co/RwbkxEFaZX', '0', '0', '', '', '', 'https://tinyurl.com/ydr6k45n;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['8092968', '1417429770577629213', '2021-07-20 10:22:46+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Covid-19: più che triplicati i contagi al confine con il Myanmar. Crescono dubbi sui vaccini cinesi']
#
# ['https://t.co/KmOZjp53ss', '0', '0', '', '', '', 'https://tinyurl.com/yze8rkbx;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['8153642', '1417756109453119489', '2021-07-21 07:59:31+00:00', '133750534', 'musicco63', '', '', 'it', '1.0', "'La maggior parte dei casi segnalati in Italia sono stati identificati negli ultimi 14 giorni in "]
#
# ['soggetti non completamente vaccinati (non hanno ricevuto il']
#
# ["vaccino SARS-CoV-2 o vaccinati con la prima dose o con il vaccino monodose entro 14gg)' https://t.co/l1TliNoGRU", '0', '0', '', '', '', 'http://www.quotidianosanita.it/allegati/create_pdf.php?all=6820167.pdf;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['10070751', '1430269368542408704', '2021-08-24 20:42:45+00:00', '1229137491560685569', 'GRANDEUROPE1', '', '', 'fr', '1.0', 'Le psychiatre Alessandro Meluzzi dénonce :']
#
# ['                                                                                                            https://t.co/0edysdpUf5', '0', '0', '', '', '', 'https://twitter.com/RadioSavana/status/1429041840397946886;', '1', '0', '0', '0', '', '', '', 'La denuncia dello psichiatra Alessandro Meluzzi: "Buona parte di coloro che si sono vaccinati, da una certa sfera in avanti, hanno fatto falsi vaccini. Sono sicuro di questo, lo hanno proposto anche a me!" https://t.co/kJWQdnGGHv https://t.co/gnaDBXiXUH', '', '', '', 'https://t.me/RadioSavana;', '', '2021-08-21 11:24:59+00:00', '1429041840397946886', '1100776937004457984', 'RadioSavana', '', '', '', '']
#
# ['10143613', '1430807903422844931', '2021-08-26 08:22:41+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Tokyo: sospese 1.63 milioni di dosi del vaccino anti-Covid di Moderna']
#
# ['https://t.co/Er3QYhbMlB', '0', '0', '', '', '', 'https://tinyurl.com/yjgkdujd;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['10143639', '1430808000936165380', '2021-08-26 08:23:05+00:00', '1111445345010094080', 'AfricaNotizie', '', '', 'it', '0.0', '', '0', '0', 'Tokyo: sospese 1.63 milioni di dosi del vaccino anti-Covid di Moderna']
#
# ['https://t.co/Er3QYhbMlB', 'AsiaNewsIT;', '', 'https://tinyurl.com/yjgkdujd;', '0', '0', '0', '1', '', '', '', '', '1430807903422844931', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['10143690', '1430808174207115274', '2021-08-26 08:23:46+00:00', '370895961', 'suitetti', '', '', 'it', '0.0', '', '0', '0', 'Tokyo: sospese 1.63 milioni di dosi del vaccino anti-Covid di Moderna']
#
# ['https://t.co/Er3QYhbMlB', 'AsiaNewsIT;', '', 'https://tinyurl.com/yjgkdujd;', '0', '0', '0', '1', '', '', '', '', '1430807903422844931', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['10214936', '1431244474106134538', '2021-08-27 13:17:28+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Yangon: i militari adesso vogliono vaccinare i rohingya contro il Covid']
#
# ['https://t.co/a4mj37kPsE', '0', '0', '', '', '', 'https://tinyurl.com/yfqekd73;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['10505647', '1433330064498757639', '2021-09-02 07:24:52+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Pyongyang rifiuta 3 milioni di dosi di vaccino cinese']
#
# ['https://t.co/qvre27JX6O', '0', '0', '', '', '', 'https://tinyurl.com/yenqfzke;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['10505967', '1433331580873887744', '2021-09-02 07:30:53+00:00', '85129926', 'Idl3', '', '', 'it', '0.0', '', '0', '0', 'Pyongyang rifiuta 3 milioni di dosi di vaccino cinese']
#
# ['https://t.co/qvre27JX6O', 'AsiaNewsIT;', '', 'https://tinyurl.com/yenqfzke;', '0', '0', '0', '1', '', '', '', '', '1433330064498757639', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['10514843', '1433374938979872768', '2021-09-02 10:23:10+00:00', '1111445345010094080', 'AfricaNotizie', '', '', 'it', '0.0', '', '0', '0', 'Pyongyang rifiuta 3 milioni di dosi di vaccino cinese']
#
# ['https://t.co/qvre27JX6O', 'AsiaNewsIT;', '', 'https://tinyurl.com/yenqfzke;', '0', '0', '0', '1', '', '', '', '', '1433330064498757639', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
#
# ['11586978', '1440713425861025795', '2021-09-22 16:23:42+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Yangon: le milizie ribelli ricevono vaccini anti-Covid da Pechino']
#
# ['https://t.co/9HDbAudXEb', '0', '0', '', '', '', 'https://tinyurl.com/ydukzygg;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['11619786', '1441015959909773319', '2021-09-23 12:25:52+00:00', '111260090', 'AsiaNewsIT', '', '', 'it', '0.0', 'Biden: il Quad produrrà almeno un miliardo di vaccini in India']
#
# ['https://t.co/A0AOSu0i7l', '0', '0', '', '', '', 'https://tinyurl.com/ye8w2bkr;', '0', '0', '1', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
#
# ['11621034', '1441022523743916034', '2021-09-23 12:51:57+00:00', '1111445345010094080', 'AfricaNotizie', '', '', 'it', '0.0', '', '0', '0', 'Biden: il Quad produrrà almeno un miliardo di vaccini in India']
#
# ['https://t.co/A0AOSu0i7l', 'AsiaNewsIT;', '', 'https://tinyurl.com/ye8w2bkr;', '0', '0', '0', '1', '', '', '', '', '1441015959909773319', '111260090', 'AsiaNewsIT', '', '', '', '', '', '', '', '', '', '']
